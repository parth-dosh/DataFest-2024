# %%
cd MyDrive
# Out:
# /content/drive/MyDrive

# %%
#Relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
responses_df = pd.read_csv('responses.csv', low_memory=False)

# %%
responses_df.head()
# Out:
#                                                 book    release  \
# 0  College / Advanced Statistics and Data Science...  v5.0-exp2
# 1  College / Advanced Statistics and Data Science...  v5.0-exp2
# 2  College / Advanced Statistics and Data Science...  v5.0-exp2
# 3  College / Advanced Statistics and Data Science...  v5.0-exp2
# 4  College / Advanced Statistics and Data Science...  v5.0-exp2
#
#                                              chapter  \
# 0  Chapter 1 - Welcome to Statistics: A Modeling ...
# 1  Chapter 1 - Welcome to Statistics: A Modeling ...
# 2  Chapter 1 - Welcome to Statistics: A Modeling ...
# 3  Chapter 1 - Welcome to Statistics: A Modeling ...
# 4  Chapter 1 - Welcome to Statistics: A Modeling ...
#
#                           page  chapter_number  section_number  review_flag  \
# 0  1.3 Doing Statistics with R             1.0             3.0        False
# 1  1.3 Doing Statistics with R             1.0             3.0        False
# ...

# %%
print(responses_df.columns)
responses_df.describe()
# Out:
# Index(['book', 'release', 'chapter', 'page', 'chapter_number',
#        'section_number', 'review_flag', 'institution_id', 'class_id',
#        'student_id', 'item_id', 'item_type', 'response', 'prompt',
#        'points_possible', 'points_earned', 'dt_submitted', 'completes_page',
#        'attempt', 'user_agent', 'lrn_response_id', 'lrn_activity_reference',
#        'lrn_question_reference', 'lrn_question_position', 'lrn_type',
#        'lrn_dt_started', 'lrn_dt_saved', 'lrn_status', 'lrn_option_0',
#        'lrn_option_1', 'lrn_option_2', 'lrn_option_3', 'lrn_option_4',
#        'lrn_option_5', 'lrn_option_6', 'lrn_option_7', 'lrn_option_8',
#        'lrn_option_9', 'lrn_option_10', 'lrn_option_11'],
#       dtype='object')
#        chapter_number  section_number  points_possible  points_earned  \
# count   237909.000000   237909.000000         195577.0  195388.000000
# mean         6.402860        6.303637              1.0       0.604894
# ...

# %%
columns_to_keep = ['item_id', 'attempt', 'student_id']
respond_df = responses_df[columns_to_keep]
respond_df.head()
# Out:
#   item_id  attempt                            student_id
# 0   ch1-0        1  0780b2c5-b260-4a31-816e-e91ce8b403a0
# 1   ch1-0        1  ceacd30b-36ff-413e-9d7d-c389ad5086cf
# 2   ch1-0        1  ba593149-8b3c-4e1e-8df9-2b470c49a4f4
# 3   ch1-0        1  1bacdb33-5165-44c1-9aa5-b6a904e6c463
# 4   ch1-0        1  646acd2f-5a8b-4629-b753-faff3ff49b8c

# %%
respon_df = respond_df.groupby('student_id')['attempt'].mean().reset_index()
respon_df
# Out:
#                                student_id   attempt
# 0    001824fb-a2fd-431d-aef6-7a1250d97a62  1.082137
# 1    041a771b-41cc-4b36-928d-ec321f918db5  1.229402
# 2    04347fe5-e55a-4adc-86f2-a156ddfcfc13  1.044462
# 3    045d0e87-585c-4126-a2c0-c744effb11b2  1.418260
# 4    05588964-8577-4b9f-9a5e-ddb770184d3c  1.060849
# ..                                    ...       ...
# 245  fcdfb64b-0dd7-4839-a76d-1bd3d688d5c0  1.028502
# 246  fd2a1c41-0bc1-47c6-8ab3-d238a9a648ef  1.843729
# 247  fdc4706b-6963-41e4-9a96-ce7b44b2dc46  1.181903
# 248  fe5182ec-6732-402e-91f6-a5ddec5107ba  1.146694
# 249  fef083e8-7167-4f42-82d5-d2e893aa408a  1.484778
#
# [250 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
respon_df['attempt'].plot(kind='line', figsize=(8, 4), title='attempt')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
respon_df = respon_df[respon_df['attempt']>1]
respon_df
# Out:
#                                student_id   attempt
# 0    001824fb-a2fd-431d-aef6-7a1250d97a62  1.082137
# 1    041a771b-41cc-4b36-928d-ec321f918db5  1.229402
# 2    04347fe5-e55a-4adc-86f2-a156ddfcfc13  1.044462
# 3    045d0e87-585c-4126-a2c0-c744effb11b2  1.418260
# 4    05588964-8577-4b9f-9a5e-ddb770184d3c  1.060849
# ..                                    ...       ...
# 245  fcdfb64b-0dd7-4839-a76d-1bd3d688d5c0  1.028502
# 246  fd2a1c41-0bc1-47c6-8ab3-d238a9a648ef  1.843729
# 247  fdc4706b-6963-41e4-9a96-ce7b44b2dc46  1.181903
# 248  fe5182ec-6732-402e-91f6-a5ddec5107ba  1.146694
# 249  fef083e8-7167-4f42-82d5-d2e893aa408a  1.484778
#
# [236 rows x 2 columns]

# %%
avg_attempt = respon_df['attempt'].mean()
avg_attempt
# Out:
# 1.2610280266900609

# %%
# 25th percentile
quantile_25th = respond_df['attempt'].quantile(0.25)

# 75th percentile
quantile_75th = respon_df['attempt'].quantile(0.75)

# IQR
iqr = quantile_75th - quantile_25th

print("25th Percentile:", quantile_25th)
print("75th Percentile:", quantile_75th)
print("IQR:", iqr)
# Out:
# 25th percentile: 1.3699365721548853
# 75th percentile: 1.8291370178827342
# IQR: 0.4592004457278489

# %%
quantile_75 = respon_df['attempt'].quantile(0.75)
respo_df = respon_df[respon_df['attempt']>quantile_75]
respo_df
# Out:
#                                student_id   attempt
# 3    045d0e87-585c-4126-a2c0-c744effb11b2  1.418260
# 6    08929fc3-2331-4c9a-bd15-68147ea87d01  1.450649
# 7    0a1c6dbe-74fc-4984-9721-f301535753a4  2.015097
# 9    0d5d3654-7d7e-4da2-aff1-fe5405dfca9d  2.104902
# 19   15386729-e035-4922-b941-2bb8b3eb70f0  1.335211
# 21   175dc771-9442-4269-9507-9066fa4650cc  1.576023
# 25   198a38f3-1cf8-4d24-af3d-30417f8adad6  1.427455
# 32   1ded6d19-2b2d-4955-abaa-22d1ff8bd64f  1.286038
# 39   288cb6e5-e750-4164-946d-f72bdd63ae74  6.839604
# 40   2995b8ed-3884-4ccb-a57e-f1003f786842  1.532481
# 46   2e2f4cdc-2ebc-432a-bfbd-0666164df7ea  1.435897
# 48   2eac3fe9-ff5f-405a-90ed-a3b959949151  1.893382
# 53   30929ccd-7625-4d58-8e4a-005f264e5531  1.328956
# 58   339ea252-7d31-4dc5-908b-c4a058ce393a  1.565310
# 59   358dde6e-b5ae-4fa4-898e-05cfff311129  1.323892
# 60   37309374-d137-4976-93a8-a2f6b2734a98  2.000000
# 66   40ecbe87-9bed-4bb4-b78d-705c6af273f3  1.377119
# ...

# %%
from matplotlib import pyplot as plt
respo_df['attempt'].plot(kind='line', figsize=(8, 4), title='attempt')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
#  iqr,  25th and 75th percentile for the 'attempt' column in respon_df

q1 = respo_df['attempt'].quantile(0.25)
q3 = respo_df['attempt'].quantile(0.75)
iqr = q3 - q1
print('25th percentile:', q1)
print('75th percentile:', q3)
print('IQR:', iqr)
# Out:
# 25th percentile: 1.3699365721548853
# 75th percentile: 1.8291370178827342
# IQR: 0.4592004457278489

# %%
# dataframe respo_df: bar plot

respo_df.plot.bar(x='item_id', y='attempt')
# Out:
# <Axes: xlabel='item_id'>

# %%
cluster_df = pd.read_csv('cluster_data.csv')

# %%
# changing cluster_df dataframe to contain only those values that belong in cluster 2

cluster_2_df = cluster_df[cluster_df['Cluster'] == 2]
cluster_2_df.head()
# Out:
#     thoughtfulness      engaged     Pulse       EOC  Rev  Cluster  \
# 4         0.000000   62052885.0  3.666667  0.638054   11        2
# 5        24.342857   74220370.0  4.050000  0.549085  156        2
# 8         0.000000   34717887.0  3.583333  0.570394   47        2
# 9         0.000000   81080748.0  4.363636  0.531335   51        2
# 16       20.948571  126434874.0  4.000000  0.621842   27        2
#
#                               student_id
# 4   01805fac-7187-40e3-8a7e-1dda3c6c87f2
# 5   01bd8559-8276-4299-9ee4-248c4b4af2a9
# 8   040852c0-3b9c-4fc6-8229-d7ba8264e9ce
# 9   045d0e87-585c-4126-a2c0-c744effb11b2
# 16  08706d0e-b702-4d98-87a3-1e74641e1751

# %%
cluster_1_df = cluster_df[cluster_df['Cluster'] == 1]
cluster_1_df.head()
# Out:
#     thoughtfulness      engaged     Pulse       EOC  Rev  Cluster  \
# 2         0.000000   93017434.0  3.850000  0.849111   34        1
# 3         0.000000   14547228.0  4.000000  0.854545   20        1
# 6        28.630682  127731181.0  4.568182  0.872400   65        1
# 13       18.096591  105993772.0  3.545455  0.751831  143        1
# 15        0.000000   72435592.0  3.850000  0.711001    8        1
#
#                               student_id
# 2   00fe5bb2-6b64-4a36-a706-eac4dc124ea7
# 3   016e2fcf-0cc2-42ad-844d-e1057b5081cc
# 6   02b7468a-2c49-474d-8c6b-3188904fd85e
# 13  062f021e-8297-41e6-a8fe-54a382ab7404
# 15  0790387e-e285-442d-b660-a004d0a5a16f

# %%
# mean number of 'attempts' column for the items in respo_df taken from students in this (cluster_df) data frame (by cross-referencing 'student_id' in both)

import pandas as pd
merged_df_2 = pd.merge(respo_df, cluster_2_df, on='student_id', how='inner')
mean_attempts_2 = merged_df_2['attempt'].mean()
print(f"Mean number of attempts for items in respo_df taken from students in cluster_df: {mean_attempts_2}")
# Out:
# Mean number of attempts for items in respo_df taken from students in cluster_df: 1.5504490501646007

# %%
#mean number of 'attempts' column for the items in respo_df taken from students in tis (cluster_df) data frame (by cross-referencing 'student_id' in both)

import pandas as pd
merged_df_1 = pd.merge(respo_df, cluster_1_df, on='student_id', how='inner')
mean_attempts_1 = merged_df_1['attempt'].mean()
print(f"Mean number of attempts for items in respo_df taken from students in cluster_df: {mean_attempts_1}")
# Out:
# Mean number of attempts for items in respo_df taken from students in cluster_df: 1.3579345288758418

# %%
cluster_0_df = cluster_df[cluster_df['Cluster'] == 0]
cluster_0_df.head()
# Out:
#     thoughtfulness      engaged     Pulse       EOC  Rev  Cluster  \
# 0        23.323864  185561041.0  4.159091  0.748087  274        0
# 1         0.000000  158365058.0  4.431818  0.567986   27        0
# 7         0.000000  214157007.0  4.416667  0.808143  185        0
# 10        0.000000  171880251.0  4.204545  0.810157  238        0
# 11       30.579545  165582368.0  4.477273  0.771428  143        0
#
#                               student_id
# 0   001824fb-a2fd-431d-aef6-7a1250d97a62
# 1   0096491a-77bf-4e79-b906-fc7a8e5e57a6
# 7   03e91d96-b20b-4938-8e6f-69389ba9279b
# 10  05171e5f-ae7c-47c6-bcc8-72473067a82a
# 11  0556b794-cd80-4af6-8cfa-8055462c215a

# %%
# mean number of 'attempts' column for the items in respo_df taken from students in this (cluster_df) data frame (by cross-referencing 'student_id' in both)

import pandas as pd
merged_df_0 = pd.merge(respo_df, cluster_0_df, on='student_id', how='inner')
mean_attempts_0 = merged_df_0['attempt'].mean()
print(f"Mean number of attempts for items in respo_df taken from students in cluster_df: {mean_attempts_0}")
# Out:
# Mean number of attempts for items in respo_df taken from students in cluster_df: 1.4882524963993393

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# boxplot for each merged dataframe
sns.boxplot(x="Cluster", y="attempt", data=pd.concat([merged_df_0, merged_df_1, merged_df_2]))

#title and labels
plt.title("Comparison of Attempts by Cluster")
plt.xlabel("Cluster")
plt.ylabel("Attempts")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# boxplot
sns.boxplot(x="Cluster", y="attempt", data=pd.concat([merged_df_0, merged_df_1, merged_df_2]), showfliers=False)

plt.title("Comparison of Attempts by Cluster")
plt.xlabel("Cluster")
plt.ylabel("Attempts")

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# boxplot
sns.boxplot(
    x="Cluster",
    y="attempt",
    data=pd.concat([merged_df_0, merged_df_1, merged_df_2]),
    palette=["#9e80a8", "#3c958e", "#fbe601"],
    showfliers=False,
)

plt.title("Comparison of Attempts by Cluster")
plt.xlabel("Cluster")
plt.ylabel("Attempts")


plt.show()
# Out:
# <ipython-input-87-861fc429fcbf>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
