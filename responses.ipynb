# %%
#Here are a set of libraries we imported to complete this assignment.
#Feel free to use these or equivalent libraries for your implementation
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # this is used for the plot the graph
import os
import seaborn as sns # used for plot interactive graph.
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix
import sklearn.metrics.cluster as smc
from sklearn.model_selection import KFold


from matplotlib import pyplot
import itertools

# %matplotlib inline

import random

random.seed(42)

# %%
from transformers import BertModel, BertTokenizer

# Load TinyBERT tokenizer and mode
tokenizer = BertTokenizer.from_pretrained('prajjwal1/bert-tiny')
model = BertModel.from_pretrained('prajjwal1/bert-tiny')

# %%
responses = pd.read_csv('responses.csv', usecols=range(0, 19))
#responses = pd.read_csv('responses.csv')
responses.head()
# Out:
#                                                 book    release  \
# 0  College / Advanced Statistics and Data Science...  v5.0-exp2
# 1  College / Advanced Statistics and Data Science...  v5.0-exp2
# 2  College / Advanced Statistics and Data Science...  v5.0-exp2
# 3  College / Advanced Statistics and Data Science...  v5.0-exp2
# 4  College / Advanced Statistics and Data Science...  v5.0-exp2
#
#                                              chapter  \
# 0  Chapter 1 - Welcome to Statistics: A Modeling ...
# 1  Chapter 1 - Welcome to Statistics: A Modeling ...
# 2  Chapter 1 - Welcome to Statistics: A Modeling ...
# 3  Chapter 1 - Welcome to Statistics: A Modeling ...
# 4  Chapter 1 - Welcome to Statistics: A Modeling ...
#
#                           page  chapter_number  section_number  review_flag  \
# 0  1.3 Doing Statistics with R             1.0             3.0        False
# 1  1.3 Doing Statistics with R             1.0             3.0        False
# 2  1.3 Doing Statistics with R             1.0             3.0        False
# 3  1.3 Doing Statistics with R             1.0             3.0        False
# 4  1.3 Doing Statistics with R             1.0             3.0        False
#
#                          institution_id                              class_id  \
# 0  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 1  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 2  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 3  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 4  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
#
#                              student_id item_id item_type  \
# 0  7535ba88-d131-4eee-b392-36f5e11c85ce   ch1-0      code
# 1  1d4a6d2c-0cb1-4d19-9218-b673982e9f2f   ch1-0      code
# 2  94a09f74-2d8c-4379-92ad-7fe5b02ec188   ch1-0      code
# 3  20a47775-9594-4800-9857-fd09633c561f   ch1-0      code
# 4  7ea35ae6-4aee-4c17-b96a-e1ecb27f2b42   ch1-0      code
#
#                                             response  \
# 0  # type whatever you want\n# see... blah blah b...
# 1  # type whatever you want\n# see... blah blah b...
# 2                      # what is 5+5\n# see a lion\n
# 3            # Sample comment\n# Sample commment 2\n
# 4          # type whatever you want\n# I like cows\n
#
#                                               prompt  points_possible  \
# 0  # type whatever you want\n# see... blah blah b...              1.0
# 1  # type whatever you want\n# see... blah blah b...              1.0
# 2  # type whatever you want\n# see... blah blah b...              1.0
# 3  # type whatever you want\n# see... blah blah b...              1.0
# 4  # type whatever you want\n# see... blah blah b...              1.0
#
#    points_earned          dt_submitted  completes_page  attempt
# 0            1.0  2023-04-04T05:42:37Z            True        1
# 1            1.0  2023-03-30T05:04:23Z            True        1
# 2            1.0  2023-04-04T06:25:59Z            True        1
# 3            1.0  2023-04-04T06:23:59Z            True        1
# 4            1.0  2023-04-04T06:35:06Z            True        1

# %%
items = pd.read_csv('items.csv')

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1335 entries, 0 to 1334
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   institution_id          1335 non-null   object
#  1   class_id                1335 non-null   object
#  2   item_id                 1335 non-null   object
#  3   item_type               1335 non-null   object
#  4   chapter                 1335 non-null   object
#  5   page                    1335 non-null   object
#  6   dcl_pre_exercise_code   0 non-null      float64
#  7   dcl_sample_code         1 non-null      object
#  8   dcl_solution            1 non-null      object
#  9   dcl_sct                 1 non-null      object
#  10  dcl_hint                0 non-null      float64
#  11  lrn_activity_reference  129 non-null    object
#  12  lrn_question_reference  1334 non-null   object
#  13  lrn_question_position   1334 non-null   float64
#  14  lrn_type                1334 non-null   object
#  15  lrn_template_name       1334 non-null   object
#  16  chapter_number          1191 non-null   float64
#  17  section_number          1191 non-null   float64
#  18  review_flag             1335 non-null   bool
# dtypes: bool(1), float64(5), object(13)
# memory usage: 189.2+ KB

# %%
unique_class_ids = responses['class_id'].unique()
# Out:
# 6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab

# %%
class_1 = responses[responses['class_id'] == unique_class_ids[0]].copy()
class_1.head()
# Out:
#                                                 book    release  \
# 0  College / Advanced Statistics and Data Science...  v5.0-exp2
# 1  College / Advanced Statistics and Data Science...  v5.0-exp2
# 2  College / Advanced Statistics and Data Science...  v5.0-exp2
# 3  College / Advanced Statistics and Data Science...  v5.0-exp2
# 4  College / Advanced Statistics and Data Science...  v5.0-exp2
#
#                                              chapter  \
# 0  Chapter 1 - Welcome to Statistics: A Modeling ...
# 1  Chapter 1 - Welcome to Statistics: A Modeling ...
# 2  Chapter 1 - Welcome to Statistics: A Modeling ...
# 3  Chapter 1 - Welcome to Statistics: A Modeling ...
# 4  Chapter 1 - Welcome to Statistics: A Modeling ...
#
#                           page  chapter_number  section_number  review_flag  \
# 0  1.3 Doing Statistics with R             1.0             3.0        False
# 1  1.3 Doing Statistics with R             1.0             3.0        False
# 2  1.3 Doing Statistics with R             1.0             3.0        False
# 3  1.3 Doing Statistics with R             1.0             3.0        False
# 4  1.3 Doing Statistics with R             1.0             3.0        False
#
#                          institution_id                              class_id  \
# 0  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 1  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 2  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 3  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 4  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
#
#                              student_id  ... lrn_dt_started lrn_dt_saved  \
# 0  0780b2c5-b260-4a31-816e-e91ce8b403a0  ...            NaN          NaN
# 1  ceacd30b-36ff-413e-9d7d-c389ad5086cf  ...            NaN          NaN
# 2  ba593149-8b3c-4e1e-8df9-2b470c49a4f4  ...            NaN          NaN
# 3  1bacdb33-5165-44c1-9aa5-b6a904e6c463  ...            NaN          NaN
# 4  646acd2f-5a8b-4629-b753-faff3ff49b8c  ...            NaN          NaN
#
#   lrn_status lrn_option_0  lrn_option_1  lrn_option_2 lrn_option_3  \
# 0        NaN          NaN           NaN           NaN          NaN
# 1        NaN          NaN           NaN           NaN          NaN
# 2        NaN          NaN           NaN           NaN          NaN
# 3        NaN          NaN           NaN           NaN          NaN
# 4        NaN          NaN           NaN           NaN          NaN
#
#    lrn_option_4  lrn_option_5 right
# 0           NaN           NaN   1.0
# 1           NaN           NaN   1.0
# 2           NaN           NaN   1.0
# 3           NaN           NaN   1.0
# 4           NaN           NaN   1.0
#
# [5 rows x 35 columns]

# %%
class_1.loc[:, 'right'] = class_1['points_earned'] / class_1['points_possible']

# %%
mean_right_by_prompt = class_1.groupby('prompt')['right'].mean()

# %%
sorted_mean_right_by_prompt = mean_right_by_prompt.sort_values()

# Display the top 5 mean prompts
top_5_mean_prompts = sorted_mean_right_by_prompt.tail(5)
print("Top 5 mean prompts:")
print(top_5_mean_prompts)

# Display the bottom 5 mean prompts
bottom_5_mean_prompts = sorted_mean_right_by_prompt.head(5)
print("\nBottom 5 mean prompts:")
print(bottom_5_mean_prompts)
# Out:
# Top 5 mean prompts:
# prompt
# Would it be possible to represent this same model, but instead of plotting height on the x-axis, plot age, and instead of drawing lines for 3 different ages, draw lines for 3 different heights? Why or why not?                                                                    NaN
# Write a word equation for the researchers’ hypothesis that both the condition and gender of the server would explain the variation in tip percentage.                                                                                                                                NaN
# You can try it yourself. Enter a random number between 1 and 20 here.                                                                                                                                                                                                                NaN
# You previously learned that a quantitative variable should go into <code>gf_histogram()</code>. Does this mean that only quantitative variables can be outcome variables? Why or why not?                                                                                            NaN
# You previously learned that categorical variables should go into <code>gf_facet_grid()</code>. Now you know that&nbsp;<code>Sex</code>&nbsp;is not only categorical, it is also the explanatory variable. Why is it useful to split up the histograms by the explanatory variable?   NaN
# Name: right, dtype: float64
#
# Bottom 5 mean prompts:
# prompt
# Assume that height is represented by $$X_{1i}$$ and age is represented by $$X_{2i}$$. Which of these models of the DGP would we reject based on the p-values in this ANOVA table? (Check all that apply.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     0.0
# <p><img alt="Option A is x-bar equals the sum of x sub-i all divided by n. Option B is y-bar equals the sum of y sub-1, y sub-2, to y sub-n all divided by n. Option C is Y-bar equals the sum of Y sub-i divided by n. Option D is Y-bar equals Y sub-i divided by the sum of n. Option E is Y-bar equals the sum of Y sub-i divided by n. Option F is Y-bar equals the sum of Y divided by n." height="215" src="https://assets.learnosity.com/organisations/430/fac9366e-acff-4775-b387-79db58b1abaa.png" width="900" /></p>\n\n<p>Examine the equations above.&nbsp;Which of them represent the mean?&nbsp;(Check all that apply.)</p>\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.0
# <pre>\n<code>Analysis of Variance Table (Type III SS)\n&nbsp;Model: FEV ~ HEIGHT + AGE\n\n&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;SS&nbsp; df&nbsp; &nbsp; &nbsp; MS&nbsp; &nbsp; &nbsp; &nbsp; F&nbsp; &nbsp; PRE &nbsp; &nbsp; p\n&nbsp;------ --------------- | ------- --- ------- -------- ------ -----\n&nbsp;&nbsp;Model (error reduced) | 376.245 &nbsp; 2 188.122 1067.956 0.7664 .0000\n&nbsp;HEIGHT &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; |&nbsp; 95.326 &nbsp; 1&nbsp; 95.326&nbsp; 541.157 0.4539 .0000\n&nbsp;&nbsp;&nbsp;&nbsp;AGE &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; | &nbsp; 6.259 &nbsp; 1 &nbsp; 6.259 &nbsp; 35.532 0.0518 .0000\n&nbsp;&nbsp;Error (from model)&nbsp; &nbsp; | 114.675 651 &nbsp; 0.176&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;\n&nbsp;------ --------------- | ------- --- ------- -------- ------ -----\n&nbsp;&nbsp;Total (empty model) &nbsp; | 490.920 653 &nbsp; 0.752&nbsp;&nbsp;&nbsp;\n</code></pre>\n\n<p>Where in this ANOVA table would we look to evaluate the multivariate model against the empty model? The row that says:</p>\n    0.0
# Which of these lines of code will calculate the p-value for <code>HomeSizeK_f</code>&nbsp;based on the shuffled sampling distribution of Fs?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  0.0
# What is the correct interpretation of the fact that the sample F falls far out in the upper tail of the sampling distribution?                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                0.0
# Name: right, dtype: float64

# %%
valid_class = ['074123e7-cd90-4500-86fe-286aaa733bf5', 'b7489f46-1d28-4c69-9901-3fb8bf9b85a6', '51711479-441b-4c02-aef7-517aca63a53f', '84444a0e-2905-46a8-bc93-5f566c0c1916', 'cc1ffb2e-5555-4109-8ad8-2d49cb54ad10', '6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab', '98119d92-8cc6-416a-972c-630351726223', '7a987176-7e55-45b5-a715-7f56c59d5f49', 'c7008a64-b43c-4eb4-bebf-07b08b9894ad', 'bc650f4f-11f0-439a-a90a-47726724c811', '79662249-02f6-48d8-aa99-1e1c0aeea77d', '34036ef8-17eb-4e96-b97e-8ec8054a290f', '8589cd83-192c-44c8-b649-cd848e519530', '3631cec9-51d3-4237-906f-a142a715be51', 'afcb6b4e-a0c0-46ce-b38c-c96329c91471', '173bd102-4560-470f-b4f1-9841e55f7f37', '0d546479-6f77-4477-9c7e-365cd36c97eb', '40e49bfa-f6cb-42fa-a3a4-b23592b799ec', '2294d558-6f5d-41c5-8d28-7b5280970f95', '97c61e74-5a20-4cf5-bf67-8f8db750d0e7', 'd0b4f5e2-6d8f-4828-91cd-3f4714b821b0', 'b16b895d-ca1d-4330-a36d-c43fb33436e5', 'ec76b77f-7635-4b9d-9975-f28bc334e336', '552ede8f-6b54-426d-8d29-abdc43a668cb', '9fad0c9e-9d3d-4eed-ada6-3959bd6d712c', '52619962-72f6-4716-9c64-1c06fe10f739', '312e145c-f6b8-4f25-a73e-4d9f5b5926c0', '60e05fa5-c986-4973-9833-16238720b727', '686478e7-82ac-4e6c-a3ec-2da0076ef868']

# %%
responses_small = responses[responses['class_id'].isin(valid_class)]

# %%
responses_small.head()
# Out:
#                                                 book    release  \
# 0  College / Advanced Statistics and Data Science...  v5.0-exp2
# 1  College / Advanced Statistics and Data Science...  v5.0-exp2
# 2  College / Advanced Statistics and Data Science...  v5.0-exp2
# 3  College / Advanced Statistics and Data Science...  v5.0-exp2
# 4  College / Advanced Statistics and Data Science...  v5.0-exp2
#
#                                              chapter  \
# 0  Chapter 1 - Welcome to Statistics: A Modeling ...
# 1  Chapter 1 - Welcome to Statistics: A Modeling ...
# 2  Chapter 1 - Welcome to Statistics: A Modeling ...
# 3  Chapter 1 - Welcome to Statistics: A Modeling ...
# 4  Chapter 1 - Welcome to Statistics: A Modeling ...
#
#                           page  chapter_number  section_number  review_flag  \
# 0  1.3 Doing Statistics with R             1.0             3.0        False
# 1  1.3 Doing Statistics with R             1.0             3.0        False
# 2  1.3 Doing Statistics with R             1.0             3.0        False
# 3  1.3 Doing Statistics with R             1.0             3.0        False
# 4  1.3 Doing Statistics with R             1.0             3.0        False
#
#                          institution_id                              class_id  \
# 0  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 1  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 2  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 3  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
# 4  292cff87-3c74-4e94-8622-233afb0427dd  6fbf5a0a-cf5d-4567-89b5-eb5c4a16c4ab
#
#                              student_id item_id item_type  \
# 0  7535ba88-d131-4eee-b392-36f5e11c85ce   ch1-0      code
# 1  1d4a6d2c-0cb1-4d19-9218-b673982e9f2f   ch1-0      code
# 2  94a09f74-2d8c-4379-92ad-7fe5b02ec188   ch1-0      code
# 3  20a47775-9594-4800-9857-fd09633c561f   ch1-0      code
# 4  7ea35ae6-4aee-4c17-b96a-e1ecb27f2b42   ch1-0      code
#
#                                             response  \
# 0  # type whatever you want\n# see... blah blah b...
# 1  # type whatever you want\n# see... blah blah b...
# 2                      # what is 5+5\n# see a lion\n
# 3            # Sample comment\n# Sample commment 2\n
# 4          # type whatever you want\n# I like cows\n
#
#                                               prompt  points_possible  \
# 0  # type whatever you want\n# see... blah blah b...              1.0
# 1  # type whatever you want\n# see... blah blah b...              1.0
# 2  # type whatever you want\n# see... blah blah b...              1.0
# 3  # type whatever you want\n# see... blah blah b...              1.0
# 4  # type whatever you want\n# see... blah blah b...              1.0
#
#    points_earned          dt_submitted  completes_page  attempt
# 0            1.0  2023-04-04T05:42:37Z            True        1
# 1            1.0  2023-03-30T05:04:23Z            True        1
# 2            1.0  2023-04-04T06:25:59Z            True        1
# 3            1.0  2023-04-04T06:23:59Z            True        1
# 4            1.0  2023-04-04T06:35:06Z            True        1

# %%
responses_small.to_csv('responses_small.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 eoc_pulse.to_csv('responses_small.csv', index=False)
#
# NameError: name 'eoc_pulse' is not defined

# %%
unique_item_types = responses_small['item_type'].unique()
print(unique_item_types)
# Out:
# ['code' 'learnosity' 'learnosity-activity']

# %%
items.head()
# Out:
#                          institution_id                              class_id  \
# 0  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 1  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 2  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 3  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 4  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
#
#                    item_id   item_type  \
# 0  First_Things_First_Quiz  learnosity
# 1  First_Things_First_Quiz  learnosity
# 2  First_Things_First_Quiz  learnosity
# 3  First_Things_First_Quiz  learnosity
# 4  First_Things_First_Quiz  learnosity
#
#                                   chapter  \
# 0  Getting Started (Don't Skip This Part)
# 1  Getting Started (Don't Skip This Part)
# 2  Getting Started (Don't Skip This Part)
# 3  Getting Started (Don't Skip This Part)
# 4  Getting Started (Don't Skip This Part)
#
#                                          page  dcl_pre_exercise_code  \
# 0  First Things First! (Don't Skip This Page)                    NaN
# 1  First Things First! (Don't Skip This Page)                    NaN
# 2  First Things First! (Don't Skip This Page)                    NaN
# 3  First Things First! (Don't Skip This Page)                    NaN
# 4  First Things First! (Don't Skip This Page)                    NaN
#
#   dcl_sample_code dcl_solution dcl_sct  dcl_hint lrn_activity_reference  \
# 0             NaN          NaN     NaN       NaN                    NaN
# 1             NaN          NaN     NaN       NaN                    NaN
# 2             NaN          NaN     NaN       NaN                    NaN
# 3             NaN          NaN     NaN       NaN                    NaN
# 4             NaN          NaN     NaN       NaN                    NaN
#
#                  lrn_question_reference  lrn_question_position lrn_type  \
# 0  1800c247-fec5-45a0-aa40-3eb7ed5eeed7                    5.0      mcq
# 1  917f3647-c6dd-473c-9e16-2e0fc4d48344                    3.0      mcq
# 2  b16697ea-eb7e-4b3d-b540-c35bf1bbd5a3                    4.0      mcq
# 3  dc46c6fb-c7a4-4590-a133-fbf6c4709aad                    2.0      mcq
# 4  ebe48663-2263-4eb0-acc4-cf71dfb1e3f8                    1.0      mcq
#
#                 lrn_template_name  chapter_number  section_number  review_flag
# 0  Multiple choice – block layout             NaN             NaN        False
# 1  Multiple choice – block layout             NaN             NaN        False
# 2  Multiple choice – block layout             NaN             NaN        False
# 3  Multiple choice – block layout             NaN             NaN        False
# 4  Multiple choice – block layout             NaN             NaN        False

# %%
unique_questions = items['lrn_type'].unique()
print(unique_questions)
# Out:
# ['mcq' 'shorttext' 'choicematrix' 'plaintext' nan 'clozeassociation'
#  'association' 'imageclozeassociation' 'sortlist' 'formulaV2']

# %%
# Assuming items and responses are your DataFrames
merged_df = pd.merge(items, responses, on=['item_id', 'class_id'])

# %%
merged_df.head()
# Out:
#                        institution_id_x                              class_id  \
# 0  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 1  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 2  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 3  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 4  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
#
#                    item_id item_type_x  \
# 0  First_Things_First_Quiz  learnosity
# 1  First_Things_First_Quiz  learnosity
# 2  First_Things_First_Quiz  learnosity
# 3  First_Things_First_Quiz  learnosity
# 4  First_Things_First_Quiz  learnosity
#
#                                 chapter_x  \
# 0  Getting Started (Don't Skip This Part)
# 1  Getting Started (Don't Skip This Part)
# 2  Getting Started (Don't Skip This Part)
# 3  Getting Started (Don't Skip This Part)
# 4  Getting Started (Don't Skip This Part)
#
#                                        page_x  dcl_pre_exercise_code  \
# 0  First Things First! (Don't Skip This Page)                    NaN
# 1  First Things First! (Don't Skip This Page)                    NaN
# 2  First Things First! (Don't Skip This Page)                    NaN
# 3  First Things First! (Don't Skip This Page)                    NaN
# 4  First Things First! (Don't Skip This Page)                    NaN
#
#   dcl_sample_code dcl_solution dcl_sct  ...  \
# 0             NaN          NaN     NaN  ...
# 1             NaN          NaN     NaN  ...
# 2             NaN          NaN     NaN  ...
# 3             NaN          NaN     NaN  ...
# 4             NaN          NaN     NaN  ...
#
#                        institution_id_y                            student_id  \
# 0  292cff87-3c74-4e94-8622-233afb0427dd  b03877b2-5f20-495c-8e28-d9179bff0eb9
# 1  292cff87-3c74-4e94-8622-233afb0427dd  b03877b2-5f20-495c-8e28-d9179bff0eb9
# 2  292cff87-3c74-4e94-8622-233afb0427dd  4f025cde-00fb-4c70-907f-5106446d9b5b
# 3  292cff87-3c74-4e94-8622-233afb0427dd  4f025cde-00fb-4c70-907f-5106446d9b5b
# 4  292cff87-3c74-4e94-8622-233afb0427dd  4f025cde-00fb-4c70-907f-5106446d9b5b
#
#   item_type_y  response                                             prompt  \
# 0  learnosity     ["1"]  What browser should you use to work through th...
# 1  learnosity     ["2"]  What does it mean if there is no <strong>Try A...
# 2  learnosity     ["2"]  What does it mean if there is no <strong>Try A...
# 3  learnosity     ["3"]  This&nbsp;button appears in the lower right co...
# 4  learnosity     ["1"]  What browser should you use to work through th...
#
#   points_possible  points_earned          dt_submitted  completes_page attempt
# 0             1.0            1.0  2023-01-14T23:58:51Z            True       1
# 1             1.0            1.0  2023-01-14T23:58:51Z            True       1
# 2             1.0            1.0  2023-01-14T23:08:13Z            True       1
# 3             1.0            0.0  2023-01-14T23:08:13Z            True       1
# 4             1.0            1.0  2023-01-14T23:08:13Z            True       1
#
# [5 rows x 36 columns]

# %%
# Assuming items and responses are your merged DataFrame
plaintext_rows = merged_df[merged_df['lrn_type'] == 'plaintext']

# %%
plaintext_rows.head()
# Out:
#                            institution_id_x  \
# 20000  292cff87-3c74-4e94-8622-233afb0427dd
# 20001  292cff87-3c74-4e94-8622-233afb0427dd
# 20002  292cff87-3c74-4e94-8622-233afb0427dd
# 20003  292cff87-3c74-4e94-8622-233afb0427dd
# 20004  292cff87-3c74-4e94-8622-233afb0427dd
#
#                                    class_id        item_id  \
# 20000  074123e7-cd90-4500-86fe-286aaa733bf5  Pre_Conf_Conc
# 20001  074123e7-cd90-4500-86fe-286aaa733bf5  Pre_Conf_Conc
# 20002  074123e7-cd90-4500-86fe-286aaa733bf5  Pre_Conf_Conc
# 20003  074123e7-cd90-4500-86fe-286aaa733bf5  Pre_Conf_Conc
# 20004  074123e7-cd90-4500-86fe-286aaa733bf5  Pre_Conf_Conc
#
#                item_type_x                               chapter_x  \
# 20000  learnosity-activity  Getting Started (Don't Skip This Part)
# 20001  learnosity-activity  Getting Started (Don't Skip This Part)
# 20002  learnosity-activity  Getting Started (Don't Skip This Part)
# 20003  learnosity-activity  Getting Started (Don't Skip This Part)
# 20004  learnosity-activity  Getting Started (Don't Skip This Part)
#
#                           page_x  dcl_pre_exercise_code dcl_sample_code  \
# 20000  Student Survey (REQUIRED)                    NaN             NaN
# 20001  Student Survey (REQUIRED)                    NaN             NaN
# 20002  Student Survey (REQUIRED)                    NaN             NaN
# 20003  Student Survey (REQUIRED)                    NaN             NaN
# 20004  Student Survey (REQUIRED)                    NaN             NaN
#
#       dcl_solution dcl_sct  ...                      institution_id_y  \
# 20000          NaN     NaN  ...  292cff87-3c74-4e94-8622-233afb0427dd
# 20001          NaN     NaN  ...  292cff87-3c74-4e94-8622-233afb0427dd
# 20002          NaN     NaN  ...  292cff87-3c74-4e94-8622-233afb0427dd
# 20003          NaN     NaN  ...  292cff87-3c74-4e94-8622-233afb0427dd
# 20004          NaN     NaN  ...  292cff87-3c74-4e94-8622-233afb0427dd
#
#                                  student_id          item_type_y  \
# 20000  53f3a54c-37ba-49c0-a9eb-a9b1734c1853  learnosity-activity
# 20001  53f3a54c-37ba-49c0-a9eb-a9b1734c1853  learnosity-activity
# 20002  53f3a54c-37ba-49c0-a9eb-a9b1734c1853  learnosity-activity
# 20003  3cc14c3e-8586-4017-80c1-152954ebbe2a  learnosity-activity
# 20004  3cc14c3e-8586-4017-80c1-152954ebbe2a  learnosity-activity
#
#                                                 response  \
# 20000                                              [[0]]
# 20001                                              [[4]]
# 20002  I'm concerned that I'm not going to do well an...
# 20003  Not concerned at all. Looking forward to this ...
# 20004                                              [[0]]
#
#                                                   prompt points_possible  \
# 20000                                                NaN             NaN
# 20001                                                NaN             NaN
# 20002  When I think about this class, I'm concerned t...             NaN
# 20003  When I think about this class, I'm concerned t...             NaN
# 20004                                                NaN             NaN
#
#        points_earned          dt_submitted  completes_page attempt
# 20000            NaN  2022-12-22T07:27:53Z           False       1
# 20001            NaN  2022-12-22T07:27:53Z           False       1
# 20002            NaN  2022-12-22T07:27:53Z           False       1
# 20003            NaN  2022-12-23T00:39:10Z            True       1
# 20004            NaN  2022-12-23T00:39:10Z            True       1
#
# [5 rows x 36 columns]

# %%
# Assuming plaintext_rows_copy is your DataFrame with rows where lrn_type is 'plaintext'
plaintext_rows = plaintext_rows.loc[:, ['class_id', 'student_id', 'response', 'prompt']]

# %%
# Assuming plaintext_rows is your DataFrame with rows where lrn_type is 'plaintext'
plaintext_rows_copy = plaintext_rows.copy()

# Now, drop rows with any missing values from the copied DataFrame
plaintext_rows_copy.dropna(inplace=True)

# %%
plaintext_rows_copy.head()
# Out:
#                                    class_id  \
# 20002  074123e7-cd90-4500-86fe-286aaa733bf5
# 20003  074123e7-cd90-4500-86fe-286aaa733bf5
# 20006  074123e7-cd90-4500-86fe-286aaa733bf5
# 20015  074123e7-cd90-4500-86fe-286aaa733bf5
# 20018  074123e7-cd90-4500-86fe-286aaa733bf5
#
#                                  student_id  \
# 20002  53f3a54c-37ba-49c0-a9eb-a9b1734c1853
# 20003  3cc14c3e-8586-4017-80c1-152954ebbe2a
# 20006  919db96b-3670-4a1e-9a4d-9591f38f8ef4
# 20015  41422302-20a7-417e-88ea-3b29631a418d
# 20018  9bb87c84-0d85-4fd6-bdf9-197541697b0d
#
#                                                 response  \
# 20002  I'm concerned that I'm not going to do well an...
# 20003  Not concerned at all. Looking forward to this ...
# 20006  I’m concerned that I will fall behind in R cod...
# 20015                   I will struggle with mathematics
# 20018  I'm concerned that I will do well on homework ...
#
#                                                   prompt
# 20002  When I think about this class, I'm concerned t...
# 20003  When I think about this class, I'm concerned t...
# 20006  When I think about this class, I'm concerned t...
# 20015  When I think about this class, I'm concerned t...
# 20018  When I think about this class, I'm concerned t...

# %%
import pandas as pd
import spacy

# Load spaCy model
nlp = spacy.load("en_core_web_md")  # or any other pre-trained model
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 import spacy
#       4 # Load spaCy model
#       5 nlp = spacy.load("en_core_web_md")
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\__init__.py:14
#      11 from thinc.api import prefer_gpu, require_gpu, require_cpu  # noqa: F401
#      12 from thinc.api import Config
# ---> 14 from . import pipeline  # noqa: F401
#      15 from .cli.info import info  # noqa: F401
#      16 from .glossary import explain  # noqa: F401
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\pipeline\__init__.py:1
# ----> 1 from .attributeruler import AttributeRuler
#       2 from .dep_parser import DependencyParser
#       3 from .entity_linker import EntityLinker
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\pipeline\attributeruler.py:6
#       3 import srsly
#       4 from pathlib import Path
# ----> 6 from .pipe import Pipe
#       7 from ..errors import Errors
#       8 from ..training import Example
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\pipeline\pipe.pyx:8, in init spacy.pipeline.pipe()
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\training\__init__.py:11
#       9 from .batchers import minibatch_by_padded_size, minibatch_by_words  # noqa: F401
#      10 from .loggers import console_logger  # noqa: F401
# ---> 11 from .callbacks import create_copy_from_base_model
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\training\callbacks.py:3
#       1 from typing import Callable, Optional
#       2 from ..errors import Errors
# ----> 3 from ..language import Language
#       4 from ..util import load_model, registry, logger
#       7 @registry.callbacks("spacy.copy_from_base_model.v1")
#       8 def create_copy_from_base_model(
#       9     tokenizer: Optional[str] = None,
#      10     vocab: Optional[str] = None,
#      11 ) -> Callable[[Language], Language]:
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\language.py:25
#      23 from .pipe_analysis import validate_attrs, analyze_pipes, print_pipe_analysis
#      24 from .training import Example, validate_examples
# ---> 25 from .training.initialize import init_vocab, init_tok2vec
#      26 from .scorer import Scorer
#      27 from .util import registry, SimpleFrozenList, _pipe, raise_error
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\training\initialize.py:14
#      11 from itertools import islice
#      12 import warnings
# ---> 14 from .pretrain import get_tok2vec_ref
#      15 from ..lookups import Lookups
#      16 from ..vectors import Vectors, Mode as VectorsMode
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\training\pretrain.py:16
#      14 from ..errors import Errors
#      15 from ..tokens import Doc
# ---> 16 from ..schemas import ConfigSchemaPretrain
#      17 from ..util import registry, load_model_from_config, dot_to_object
#      20 def pretrain(
#      21     config: Config,
#      22     output_dir: Path,
#    (...)
#      26     silent: bool = True,
#      27 ):
#
# File ~\Conda\envs\datafest\lib\site-packages\spacy\schemas.py:216
#     210 UnderscoreValue = Union[
#     211     TokenPatternString, TokenPatternNumber, str, int, float, list, bool
#     212 ]
#     213 IobValue = Literal["", "I", "O", "B", 0, 1, 2, 3]
# --> 216 class TokenPattern(BaseModel):
#     217     orth: Optional[StringValue] = None
#     218     text: Optional[StringValue] = None
#
# File ~\Conda\envs\datafest\lib\site-packages\pydantic\main.py:299, in pydantic.main.ModelMetaclass.__new__()
#
# File ~\Conda\envs\datafest\lib\site-packages\pydantic\fields.py:411, in pydantic.fields.ModelField.infer()
#
# File ~\Conda\envs\datafest\lib\site-packages\pydantic\fields.py:342, in pydantic.fields.ModelField.__init__()
#
# File ~\Conda\envs\datafest\lib\site-packages\pydantic\fields.py:451, in pydantic.fields.ModelField.prepare()
#
# File ~\Conda\envs\datafest\lib\site-packages\pydantic\fields.py:545, in pydantic.fields.ModelField._type_analysis()
#
# File ~\Conda\envs\datafest\lib\site-packages\pydantic\fields.py:550, in pydantic.fields.ModelField._type_analysis()
#
# File ~\Conda\envs\datafest\lib\typing.py:774, in _GenericAlias.__subclasscheck__(self, cls)
#     772 if self._special:
#     773     if not isinstance(cls, _GenericAlias):
# --> 774         return issubclass(cls, self.__origin__)
#     775     if cls._special:
#     776         return issubclass(cls.__origin__, self.__origin__)
#
# TypeError: issubclass() arg 1 must be a class

# %%
# Function to calculate thoughtfulness score for a single response
def calculate_thoughtfulness(response, question):
    # Tokenize and get embeddings for response and question
    response_doc = nlp(response)
    question_doc = nlp(question)
    
    # Calculate similarity between response and question
    similarity_score = response_doc.similarity(question_doc)
    
    return similarity_score


# Calculate thoughtfulness score for each response and store it in a new column
df['thoughtfulness'] = df.apply(lambda row: calculate_thoughtfulness(row['responses'], row['question']), axis=1)

# Display the DataFrame with the new column
print(df)

# %%
import torch

# %%
#import pandas as pd
#import numpy as np
#from transformers import BertTokenizer, BertModel

# Load pre-trained BERT tokenizer and model
#tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
#model = BertModel.from_pretrained('bert-base-uncased')

# Function to calculate thoughtfulness score for a single response
def calculate_thoughtfulness(response):
    # Tokenize the response
    tokens = tokenizer(response, return_tensors="pt", max_length=512, truncation=True)
    
    # Use the model to obtain embeddings
    with torch.no_grad():
        # Forward pass through the model to get embeddings
        outputs = model(**tokens)
    
    # Extract embeddings from the output
    embeddings = outputs.last_hidden_state.detach().numpy()
    
    # Process the embeddings to calculate thoughtfulness score
    # Here, you can define your own logic to calculate the score
    # For demonstration, let's simply use the mean of the embeddings as the score
    thoughtfulness_score = np.mean(embeddings)
    
    # Normalize the score to range between 0 and 1
    normalized_score = (thoughtfulness_score - min_score) / (max_score - min_score)
    
    return normalized_score


# Define the minimum and maximum scores (for normalization)
min_score = float('inf')
max_score = float('-inf')

# Calculate thoughtfulness score for each response and store it in a new column
plaintext_rows_copy['thoughtfulness'] = plaintext_rows_copy['response'].apply(calculate_thoughtfulness)

# Display the DataFrame with the new column
plaintext_rows_copy.head()
# Out:
#                                    class_id  \
# 20002  074123e7-cd90-4500-86fe-286aaa733bf5
# 20003  074123e7-cd90-4500-86fe-286aaa733bf5
# 20006  074123e7-cd90-4500-86fe-286aaa733bf5
# 20015  074123e7-cd90-4500-86fe-286aaa733bf5
# 20018  074123e7-cd90-4500-86fe-286aaa733bf5
#
#                                  student_id  \
# 20002  53f3a54c-37ba-49c0-a9eb-a9b1734c1853
# 20003  3cc14c3e-8586-4017-80c1-152954ebbe2a
# 20006  919db96b-3670-4a1e-9a4d-9591f38f8ef4
# 20015  41422302-20a7-417e-88ea-3b29631a418d
# 20018  9bb87c84-0d85-4fd6-bdf9-197541697b0d
#
#                                                 response  \
# 20002  I'm concerned that I'm not going to do well an...
# 20003  Not concerned at all. Looking forward to this ...
# 20006  I’m concerned that I will fall behind in R cod...
# 20015                   I will struggle with mathematics
# 20018  I'm concerned that I will do well on homework ...
#
#                                                   prompt  thoughtfulness
# 20002  When I think about this class, I'm concerned t...             NaN
# 20003  When I think about this class, I'm concerned t...             NaN
# 20006  When I think about this class, I'm concerned t...             NaN
# 20015  When I think about this class, I'm concerned t...             NaN
# 20018  When I think about this class, I'm concerned t...             NaN

# %%
# Display unique values for thoughtfulness
unique_thoughtfulness_values = plaintext_rows_copy['thoughtfulness'].unique()
print("Unique Thoughtfulness Values:", unique_thoughtfulness_values)
# Out:
# Unique Thoughtfulness Values: [nan]

# %%
def calculate_thoughtfulness(response):
    # Split the response into words
    words = response.split()
    # Count the number of words
    word_count = len(words)
    # You can define your own logic here to map word count to a thoughtfulness score
    # For demonstration, let's simply use the word count as the thoughtfulness score
    return word_count

plaintext_rows_copy['thoughtfulness'] = plaintext_rows_copy['response'].apply(calculate_thoughtfulness)

# %%
plaintext_rows_copy.head()
# Out:
#                                    class_id  \
# 20002  074123e7-cd90-4500-86fe-286aaa733bf5
# 20003  074123e7-cd90-4500-86fe-286aaa733bf5
# 20006  074123e7-cd90-4500-86fe-286aaa733bf5
# 20015  074123e7-cd90-4500-86fe-286aaa733bf5
# 20018  074123e7-cd90-4500-86fe-286aaa733bf5
#
#                                  student_id  \
# 20002  53f3a54c-37ba-49c0-a9eb-a9b1734c1853
# 20003  3cc14c3e-8586-4017-80c1-152954ebbe2a
# 20006  919db96b-3670-4a1e-9a4d-9591f38f8ef4
# 20015  41422302-20a7-417e-88ea-3b29631a418d
# 20018  9bb87c84-0d85-4fd6-bdf9-197541697b0d
#
#                                                 response  \
# 20002  I'm concerned that I'm not going to do well an...
# 20003  Not concerned at all. Looking forward to this ...
# 20006  I’m concerned that I will fall behind in R cod...
# 20015                   I will struggle with mathematics
# 20018  I'm concerned that I will do well on homework ...
#
#                                                   prompt  thoughtfulness
# 20002  When I think about this class, I'm concerned t...              26
# 20003  When I think about this class, I'm concerned t...              24
# 20006  When I think about this class, I'm concerned t...              15
# 20015  When I think about this class, I'm concerned t...               5
# 20018  When I think about this class, I'm concerned t...              34

# %%
plaintext_rows_copy.to_csv('plaintext_rows_copy.csv', index=False)

# %%
sorted_df = plaintext_rows_copy.sort_values(by='student_id')
sorted_df.head()
# Out:
#                                     class_id  \
# 318710  074123e7-cd90-4500-86fe-286aaa733bf5
# 222190  074123e7-cd90-4500-86fe-286aaa733bf5
# 239339  074123e7-cd90-4500-86fe-286aaa733bf5
# 123405  074123e7-cd90-4500-86fe-286aaa733bf5
# 123406  074123e7-cd90-4500-86fe-286aaa733bf5
#
#                                   student_id  \
# 318710  001824fb-a2fd-431d-aef6-7a1250d97a62
# 222190  001824fb-a2fd-431d-aef6-7a1250d97a62
# 239339  001824fb-a2fd-431d-aef6-7a1250d97a62
# 123405  001824fb-a2fd-431d-aef6-7a1250d97a62
# 123406  001824fb-a2fd-431d-aef6-7a1250d97a62
#
#                                                  response  \
# 318710  The Height2Group has more categories than the ...
# 222190  Her z-score is 3 standard deviations above the...
# 239339  We know that females tend to have shorter thum...
# 123405                                                 15
# 123406  Any number  between 1 and 20 would be random b...
#
#                                                    prompt  thoughtfulness
# 318710  Why is the PRE larger in the <code>Height</cod...              13
# 222190  In what sense is the Spargle player a better g...              20
# 239339  Under the empty model, we would predict the th...              31
# 123405  You can try it yourself. Enter a random number...               1
# 123406  How did you decide what number would count as ...              22

# %%
averaged_df = plaintext_rows_copy.groupby('student_id')['thoughtfulness'].mean().reset_index()
averaged_df.head()
# Out:
#                              student_id  thoughtfulness
# 0  001824fb-a2fd-431d-aef6-7a1250d97a62       23.323864
# 1  01bd8559-8276-4299-9ee4-248c4b4af2a9       24.342857
# 2  02b7468a-2c49-474d-8c6b-3188904fd85e       28.630682
# 3  0556b794-cd80-4af6-8cfa-8055462c215a       30.579545
# 4  059a058b-784a-4a5e-8688-11ee7c2dd5e7       31.579096

# %%
averaged_df.to_csv('thought.csv', index=False)

# %%
averaged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219 entries, 0 to 218
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   student_id      219 non-null    object
#  1   thoughtfulness  219 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 3.5+ KB

# %%
df = pd.read_csv('cluster_data.csv')
df.head()
# Out:
#    thoughtfulness      engaged     Pulse       EOC  Rev  Cluster  \
# 0       23.323864  185561041.0  4.159091  0.748087  274        0
# 1        0.000000  158365058.0  4.431818  0.567986   27        0
# 2        0.000000   93017434.0  3.850000  0.849111   34        1
# 3        0.000000   14547228.0  4.000000  0.854545   20        1
# 4        0.000000   62052885.0  3.666667  0.638054   11        2
#
#                              student_id
# 0  001824fb-a2fd-431d-aef6-7a1250d97a62
# 1  0096491a-77bf-4e79-b906-fc7a8e5e57a6
# 2  00fe5bb2-6b64-4a36-a706-eac4dc124ea7
# 3  016e2fcf-0cc2-42ad-844d-e1057b5081cc
# 4  01805fac-7187-40e3-8a7e-1dda3c6c87f2

# %%
# Assuming 'student_id' is the common column
merged_df = pd.merge(df, responses_small, on='student_id')
merged_df = pd.merge(items, merged_df, on='item_id')

# Display the merged DataFrame
merged_df.head()
# Out:
#                        institution_id_x                            class_id_x  \
# 0  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 1  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 2  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 3  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 4  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
#
#                    item_id item_type_x  \
# 0  First_Things_First_Quiz  learnosity
# 1  First_Things_First_Quiz  learnosity
# 2  First_Things_First_Quiz  learnosity
# 3  First_Things_First_Quiz  learnosity
# 4  First_Things_First_Quiz  learnosity
#
#                                 chapter_x  \
# 0  Getting Started (Don't Skip This Part)
# 1  Getting Started (Don't Skip This Part)
# 2  Getting Started (Don't Skip This Part)
# 3  Getting Started (Don't Skip This Part)
# 4  Getting Started (Don't Skip This Part)
#
#                                        page_x  dcl_pre_exercise_code  \
# 0  First Things First! (Don't Skip This Page)                    NaN
# 1  First Things First! (Don't Skip This Page)                    NaN
# 2  First Things First! (Don't Skip This Page)                    NaN
# 3  First Things First! (Don't Skip This Page)                    NaN
# 4  First Things First! (Don't Skip This Page)                    NaN
#
#   dcl_sample_code dcl_solution dcl_sct  ...  \
# 0             NaN          NaN     NaN  ...
# 1             NaN          NaN     NaN  ...
# 2             NaN          NaN     NaN  ...
# 3             NaN          NaN     NaN  ...
# 4             NaN          NaN     NaN  ...
#
#                        institution_id_y                            class_id_y  \
# 0  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 1  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 2  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 3  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
# 4  292cff87-3c74-4e94-8622-233afb0427dd  074123e7-cd90-4500-86fe-286aaa733bf5
#
#   item_type_y  response                                             prompt  \
# 0  learnosity     ["1"]  What browser should you use to work through th...
# 1  learnosity     ["5"]  This&nbsp;button appears in the lower right co...
# 2  learnosity     ["1"]  Where would you go to check which pages you ha...
# 3  learnosity     ["1"]  Why would you click on the <strong>Try Again</...
# 4  learnosity     ["2"]  What does it mean if there is no <strong>Try A...
#
#   points_possible  points_earned          dt_submitted  completes_page  \
# 0             1.0            1.0  2022-12-17T05:59:54Z            True
# 1             1.0            0.0  2022-12-17T05:59:54Z            True
# 2             1.0            1.0  2022-12-17T05:59:54Z            True
# 3             1.0            1.0  2022-12-17T05:59:54Z            True
# 4             1.0            1.0  2022-12-17T05:59:54Z            True
#
#    attempt
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#
# [5 rows x 43 columns]

# %%
mid_group = merged_df[merged_df['Cluster'] == 2]
mid_group = mid_group[mid_group['completes_page'] == True]
mid_groupA = mid_group[mid_group['points_possible'] == mid_group['points_earned']]
mid_groupB = mid_group[mid_group['points_possible'] != mid_group['points_earned']]

print(mid_groupA.shape)
print(mid_groupB.shape)
# Out:
# (20445, 43)
# (72883, 43)

# %%
# Assuming your DataFrame is named 'mid_group'
column_names = mid_group.columns

# Display all the column names
print(column_names)
# Out:
# Index(['institution_id_x', 'class_id_x', 'item_id', 'item_type_x', 'chapter_x',
#        'page_x', 'dcl_pre_exercise_code', 'dcl_sample_code', 'dcl_solution',
#        'dcl_sct', 'dcl_hint', 'lrn_activity_reference',
#        'lrn_question_reference', 'lrn_question_position', 'lrn_type',
#        'lrn_template_name', 'chapter_number_x', 'section_number_x',
#        'review_flag_x', 'thoughtfulness', 'engaged', 'Pulse', 'EOC', 'Rev',
#        'Cluster', 'student_id', 'book', 'release', 'chapter_y', 'page_y',
#        'chapter_number_y', 'section_number_y', 'review_flag_y',
#        'institution_id_y', 'class_id_y', 'item_type_y', 'response', 'prompt',
#        'points_possible', 'points_earned', 'dt_submitted', 'completes_page',
#        'attempt'],
#       dtype='object')

# %%
# Calculate the distribution of lrn_type for mid_groupA
lrn_type_distribution_A = mid_groupA['lrn_type'].value_counts(normalize=True)

# Calculate the distribution of lrn_type for mid_groupB
lrn_type_distribution_B = mid_groupB['lrn_type'].value_counts(normalize=True)

# Display the distributions
print("LRN Type Distribution for Mid Group A:")
print(lrn_type_distribution_A)
print("\nLRN Type Distribution for Mid Group B:")
print(lrn_type_distribution_B)
# Out:
# LRN Type Distribution for Mid Group A:
# lrn_type
# mcq                      0.820936
# association              0.100127
# plaintext                0.052266
# clozeassociation         0.013996
# choicematrix             0.009151
# imageclozeassociation    0.003377
# shorttext                0.000098
# formulaV2                0.000049
# Name: proportion, dtype: float64
#
# LRN Type Distribution for Mid Group B:
# lrn_type
# mcq                      0.601526
# plaintext                0.202201
# choicematrix             0.083216
# shorttext                0.079237
# association              0.028210
# clozeassociation         0.002758
# imageclozeassociation    0.002744
# formulaV2                0.000110
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for 'mcq' and 'plaintext' lrn_type in mid_groupA
mid_groupA_filtered = mid_groupA[mid_groupA['lrn_type'].isin(['mcq', 'plaintext'])]

# Filter data for 'mcq' and 'plaintext' lrn_type in mid_groupB
mid_groupB_filtered = mid_groupB[mid_groupB['lrn_type'].isin(['mcq', 'plaintext'])]

# Set the color palette to viridis
sns.set_palette("viridis")

# Plotting
plt.figure(figsize=(12, 6))

# Plot for mid_groupA
plt.subplot(1, 2, 1)
sns.histplot(data=mid_groupA_filtered, x='lrn_type', binwidth=0.5, kde=False)
plt.title('Mid Group A')
plt.xlabel('LRN Type')
plt.ylabel('Count')

# Plot for mid_groupB
plt.subplot(1, 2, 2)
sns.histplot(data=mid_groupB_filtered, x='lrn_type', binwidth=0.5, kde=False)
plt.title('Mid Group B')
plt.xlabel('LRN Type')
plt.ylabel('Count')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
